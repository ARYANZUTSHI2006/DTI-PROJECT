# %% [markdown]
# # Runoff Training Notebook
# This notebook is a starter template for runoff model training.

# %%
import pandas as pd
from pathlib import Path

data_path = Path('../datasets/Kasol.xlsx')
df = pd.read_excel(data_path) if data_path.exists() else pd.DataFrame()
df.head()
